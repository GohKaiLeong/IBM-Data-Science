# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **K L Goh**
#
# Chemist

# %% [markdown]
# _I am interested in data science because some of the things that Python is capable of are quite interesting. For example, plotting maps and visualizing clusters on top of the map._

# %% [markdown]
# ### In the cell below, I am going to use the package "random" to generate a random integer, similar to dice rolling

# %%
import random
random.randint(1,6)
# Out:
# 3

# %% [markdown]
# > The logo below is of LinkedIn
#
# ![alt text](https://www.shareicon.net/data/256x256/2017/06/30/888065_logo_512x512.png "LinkedIn")
#
# [Connect with me if you want to](https://www.linkedin.com/in/gohkaileong/)
#
# ~Or maybe not~
